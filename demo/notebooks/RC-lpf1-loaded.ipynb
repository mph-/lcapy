# %%
from lcapy import Circuit, j, omega
cct = Circuit()
cct.add("""
Vi 1 0_1; down
Rs 1 2; right, size=1.5
C 2 0; down, v=v_C
W1 0_1 0; right
W2 0 0_2; right
P1 2_2 0_2; down
RL 2_2 0_2; down
W3 2 2_2;right""")
cct.draw()

# %%
H = cct.RL.V / cct.Vi.V

# %%
H(j * omega)
# Out:
#            R_L
# ─────────────────────────
# R_L + R_s⋅(ⅈ⋅C⋅R_L⋅ω + 1)

# %%
H(j * omega).magnitude
# Out:
#                 R_L
# ───────────────────────────────────
#    ________________________________
#   ╱  2    2    2  2              2
# ╲╱  C ⋅R_L ⋅R_s ⋅ω  + (R_L + R_s)

# %%
H(j * omega).phase_degrees
# Out:
# 180.0⋅atan2(-C⋅R_L⋅R_s⋅ω, R_L + R_s)
# ────────────────────────────────────
#                  π

# %%
H1 = H.subs('C', 1e-9).subs('Rs', 25e3).subs('RL', 5e3)
H1(j * omega)
# Out:
#        5000.0
# ───────────────────
# 0.125⋅ⅈ⋅ω + 30000.0

# %%
from numpy import logspace
w = logspace(2, 6, 500)
# %matplotlib inline
H1(j * omega).dB.plot(w, log_scale=True)

# %%
H1(j * omega).phase_degrees.plot(w, log_scale=True)
