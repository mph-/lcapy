# %% [markdown]
# Step response of R C circuit
# ============================

# %%
from lcapy import Circuit
cct = Circuit()
cct.add('V1 1 0 u(t); down')
cct.add('R1 1 2 4; right')
cct.add('C1 2 3 0.1; down')
cct.add('W1 0 3; right')

# %%
cct.draw()

# %%
cct.V[2]
# Out:
#      5
# ───────────
# s⋅(2⋅s + 5)

# %%
cct.v[2]
# Out:
# ⎛     -5⋅t ⎞
# ⎜     ─────⎟
# ⎜       2  ⎟
# ⎝1 - ℯ     ⎠⋅Heaviside(t)

# %%
# %matplotlib inline
cct.v[2].plot()

# %%
cct.v[2].plot()

# %%
cct.i['R1'].plot()

# %% [markdown]
# s-domain model
# --------------

# %%
cct.s_model().draw()

# %% [markdown]
# Poles and zeros
# ---------------

# %%
cct.V[2].ZPK()
# Out:
#       5
# ─────────────
# 2⋅s⋅(s + 5/2)

# %%
cct.V[2].poles()
# Out:
# {-5/2: 1, 0: 1}

# %%
cct.V[2].zeros()
# Out:
# {}

# %%
 cct.V[2].plot()
