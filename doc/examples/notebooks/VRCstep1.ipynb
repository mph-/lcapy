# %% [markdown]
# Step response of R C circuit
# ============================

# %%
from lcapy import Circuit
cct = Circuit()
cct.add('V1 1 0 u(t); down')
cct.add('R1 1 2 4; right')
cct.add('C1 2 3 0.1; down')
cct.add('W1 0 3; right')

# %%
cct.draw()

# %%
cct[2].V
# Out:
#      5
# ───────────
# s⋅(2⋅s + 5)

# %%
cct[2].v
# Out:
# ⎛     -5⋅t ⎞
# ⎜     ─────⎟
# ⎜       2  ⎟
# ⎝1 - ℯ     ⎠⋅Heaviside(t)

# %%
# %matplotlib inline
cct[2].v.plot()

# %%
cct[2].v.plot()

# %%
cct.R1.i.plot()

# %% [markdown]
# s-domain model
# --------------

# %%
cct.s_model().draw()

# %% [markdown]
# Poles and zeros
# ---------------

# %%
cct[2].V.ZPK()
# Out:
#       5
# ─────────────
# 2⋅s⋅(s + 5/2)

# %%
cct[2].V.poles()
# Out:
# /usr/lib/python2.7/dist-packages/IPython/core/formatters.py:239: FormatterWarning: Exception in image/png formatter:
# \begin{Bmatrix}- \frac{5}{2} : 1, & 0 : 1\end{Bmatrix}
# ^
# Unknown symbol: \begin (at char 0), (line:1, col:1)
#   FormatterWarning,
# {-5/2: 1, 0: 1}

# %%
cct[2].V.zeros()
# Out:
# /usr/lib/python2.7/dist-packages/IPython/core/formatters.py:239: FormatterWarning: Exception in image/png formatter:
# \begin{Bmatrix}\end{Bmatrix}
# ^
# Unknown symbol: \begin (at char 0), (line:1, col:1)
#   FormatterWarning,
# {}

# %%
 cct[2].V.plot()
