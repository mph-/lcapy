# %%
from lcapy import Circuit
cct = Circuit()
cct.add("""
V 1 0 dc 10; down
C 1 2 1e-6; right, size=2
R 2 3 2; down, size=1.5
L 3 0_1 8e-3 5; down, v=v_L, i=i
W 0 0_1; right
""")
cct.draw()

# %%
scct = cct.s_model()
scct.draw()

# %%
cct.L.V.partfrac()
# Out:
#                   ______                            ______
#           20000⋅╲╱ 7999 ⋅j                  20000⋅╲╱ 7999 ⋅j
# - ─────────────────────────────── + ───────────────────────────────
#        ⎛                ______  ⎞        ⎛                ______  ⎞
#   7999⋅⎝s + 125 + 125⋅╲╱ 7999 ⋅j⎠   7999⋅⎝s + 125 - 125⋅╲╱ 7999 ⋅j⎠

# %%
cct.L.v
# Out:
#         ______  -125⋅t    ⎛      ______  ⎞
# 40000⋅╲╱ 7999 ⋅ℯ      ⋅sin⎝125⋅╲╱ 7999 ⋅t⎠⋅Heaviside(t)
# ───────────────────────────────────────────────────────
#                           7999

# %%
cct.L.I.poles()
# Out:
# ⎧             ______                    ______     ⎫
# ⎨-125 - 125⋅╲╱ 7999 ⋅ⅈ: 1, -125 + 125⋅╲╱ 7999 ⋅ⅈ: 1⎬
# ⎩                                                  ⎭

# %%
# %matplotlib inline
from numpy import linspace
t = linspace(0, 10e-3, 400)
cct.L.v.plot(t)

# %% [markdown]
# Note, in practice, there is a 100:1 step up to a secondary coil conencted to a spark-gap.  Once the spark forms, the secondary coil is shorted out and energy is removed from the L-Circuit damping the oscillation.
