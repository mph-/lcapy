# %%
from lcapy import Circuit
cct = Circuit()
cct.add("""
V1 1 0 10; down
C1 1 2 1e-6 0; right, size=2
R1 2 3 2; down, size=1.5
L1 3 0_1 8e-3 5; down, v=v_L, i=i
W 0 0_1; right
""")
cct.draw()

# %%
scct = cct.s_model()
scct.draw()

# %%
cct.L.V.s.partfrac()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-5e361bd1a99e> in <module>()
# ----> 1 cct.L.V.s.partfrac()
#
# /usr/local/lib/python2.7/dist-packages/lcapy/netlist.pyc in __getattr__(self, attr)
#     101         and checks for an exception."""
#     102
# --> 103         return self.__getitem__(attr)
#     104
#     105     def __repr__(self):
#
# /usr/local/lib/python2.7/dist-packages/lcapy/netlist.pyc in __getitem__(self, name)
#      91             return self._elements[name + 'anon1']
#      92
# ---> 93         raise AttributeError('Unknown element or node name %s' % name)
#      94
#      95     def __getattr__(self, attr):
#
# AttributeError: Unknown element or node name L

# %%
cct.L.v

# %%
cct.L.I.s.poles()

# %%
# %matplotlib inline
from numpy import linspace
t = linspace(0, 10e-3, 400)
ax = cct.L.v.plot(t)

# %% [markdown]
# Note, in practice, there is a 100:1 step up to a secondary coil conencted to a spark-gap.  Once the spark forms, the secondary coil is shorted out and energy is removed from the L-Circuit damping the oscillation.
