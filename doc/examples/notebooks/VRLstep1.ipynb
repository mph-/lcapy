# %% [markdown]
# Step response of R L circuit
# ============================

# %%
from lcapy import Circuit, s
cct = Circuit("""
V1 1 0 {u(t)}; down
R1 1 2 4; right=2
L1 2 3 0.5; down=2
W1 0 3; right
""")
cct.draw()

# %%
cct[2].V(s)
# Out:
#     1
# 1⋅─────
#   s + 8

# %%
# %matplotlib inline
ax = cct[2].v.plot()

# %%
ax = cct[2].v.plot()

# %%
ax = cct.R1.i.plot()

# %% [markdown]
# s-domain model
# --------------

# %%
cct.s_model().draw()

# %% [markdown]
# Poles and zeros
# ---------------

# %%
cct[2].V(s).ZPK()
# Out:
#   1
# ─────
# s + 8

# %%
cct[2].V(s).poles()
# Out:
# {-8: 1}

# %%
cct[2].V(s).zeros()
# Out:
# {}

# %%
ax = cct[2].V(s).plot()
