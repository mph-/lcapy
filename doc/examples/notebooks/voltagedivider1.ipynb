# %% [markdown]
# Resistive voltage divider
# =========================

# %%
from lcapy import Circuit
cct = Circuit()
cct.add('V1 1 0 {u(t)}; down')
cct.add('R1 1 2 4; right')
cct.add('R2 2 3 6; down')
cct.add('W1 0 3; right')

# %%
cct.draw()

# %%
cct[2].V
# Out:
# ⎧   3⋅Heaviside(t)⎫
# ⎨t: ──────────────⎬
# ⎩         5       ⎭

# %%
# %matplotlib inline
ax = cct[2].v.plot()

# %%
ax = cct.R1.i.plot()
