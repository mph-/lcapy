# %% [markdown]
# Resistive voltage divider
# =========================

# %%
from lcapy import Circuit
cct = Circuit("""
V1 1 0 {u(t)}; down
R1 1 2 4; right=2
R2 2 3 6; down=2
W1 0 3; right
""")
cct.draw()

# %%
cct[2].v
# Out:
# 3⋅u(t)
# ──────
#   5

# %%
# %matplotlib inline
ax = cct[2].v.plot()

# %%
ax = cct.R1.i.plot()
