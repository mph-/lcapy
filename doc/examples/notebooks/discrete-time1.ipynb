# %%
# %matplotlib inline
from lcapy import *

# %%
h = 2 * ui(n) - ui(n-2)
h
# Out:
# 2⋅δ[n] - δ[n - 2]

# %%
h.plot();

# %%
H = h(z)
H
# Out:
#     1
# 2 - ──
#      2
#     z

# %%
ax = H.plot();

# %%
H.DTFT()
# Out:
#      -4⋅ⅉ⋅π⋅Δₜ⋅f
# 2 - ℯ

# %%
H.DTFT().subs(dt, 1).plot();

# %%
h.difference_equation()
# Out:
# y(n) = 2⋅x(n) - x(n - 2)

# %%
h.difference_equation()(z)
# Out:
#                 X(z)
# Y(z) = 2⋅X(z) - ────
#                   2
#                  z
