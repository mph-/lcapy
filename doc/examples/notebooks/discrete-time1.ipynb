# %%
# %matplotlib inline
from lcapy import *
from lcapy.discretetime import *
# Out:
# Warning, this is experimental and probably riddled with bugs!

# %%
h = 2 * ui(n) - ui(n-2)
h
# Out:
# 2⋅δ[n] - δ[n - 2]

# %%
h.plot();

# %%
H = h(z)
H
# Out:
#     1
# 2 - ──
#      2
#     z

# %%
ax = H.plot();

# %%
H.DTFT()
# Out:
#      -4⋅ⅉ⋅π⋅Δₜ⋅f
# 2 - ℯ

# %%
H.DTFT().subs(dt, 1).plot();

# %%
h.difference_equation()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/lcapy-0.42.post0-py3.5.egg/lcapy/ztransform.py in inverse_ztransform(expr, z, n, **assumptions)
#     532         try:
# --> 533             result1, result2 = inverse_ztransform_term(expr, z, n, **assumptions)
#     534         except:
#
# /usr/local/lib/python3.5/dist-packages/lcapy-0.42.post0-py3.5.egg/lcapy/ztransform.py in inverse_ztransform_term(expr, z, n, **assumptions)
#     474
# --> 475     result1, result2 = inverse_ztransform_term1(expr, z, n, **assumptions)
#     476
#
# /usr/local/lib/python3.5/dist-packages/lcapy-0.42.post0-py3.5.egg/lcapy/ztransform.py in inverse_ztransform_term1(expr, z, n, **assumptions)
#     451         return const * inverse_ztransform_product(expr, z, n,
# --> 452                                                **assumptions), sym.S.Zero
#     453
#
# ...

# %%
H.canonical()
