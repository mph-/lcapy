# %%
from lcapy import Circuit
cct = Circuit()
cct.add("""
V1 1 0, 12; down
C1 1 2 1 2; right, size=1.5, v=v_C
R2 2 0_1 2; down, size=1.5, i=i
W 0 0_1; right
""")
cct.draw()

# %%
cct.s_model().draw()
