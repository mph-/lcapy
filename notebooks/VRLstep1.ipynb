# %% [markdown]
# Step response of R L circuit
# ============================

# %%
from lcapy import Circuit
cct = Circuit()
cct.add('V1 1 0 u(t); down')
cct.add('R1 1 2 4; right')
cct.add('L1 2 3 0.5; down')
cct.add('W1 0 3; right')

# %%
cct.draw()

# %%
cct.V[2]
# Out:
#   1
# ─────
# s + 8

# %%
# %matplotlib inline
cct.v[2].plot()

# %%
cct.v[2].plot()

# %%
cct.i['R1'].plot()

# %% [markdown]
# s-domain model
# --------------

# %%
cct.s_model().draw()

# %% [markdown]
# Poles and zeros
# ---------------

# %%
cct.V[2].ZPK()
# Out:
#   1
# ─────
# s + 8

# %%
cct.V[2].poles()
# Out:
# {-8: 1}

# %%
cct.V[2].zeros()
# Out:
# {}

# %%
 cct.V[2].plot()
